# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_json("intents_dataset.json")

# %%
df.columns
# Out:
# Index(['intents'], dtype='object')

# %%
df["intents"]
# Out:
# 0     {'tag': 'greeting', 'patterns': ['Hi there', '...
# 1     {'tag': 'goodbye', 'patterns': ['Bye', 'See yo...
# 2     {'tag': 'thanks', 'patterns': ['Thanks', 'Than...
# 3     {'tag': 'noanswer', 'patterns': [], 'responses...
# 4     {'tag': 'options', 'patterns': ['How you could...
# 5     {'tag': 'adverse_drug', 'patterns': ['How to c...
# 6     {'tag': 'blood_pressure', 'patterns': ['Open b...
# 7     {'tag': 'blood_pressure_search', 'patterns': [...
# 8     {'tag': 'search_blood_pressure_by_patient_id',...
# 9     {'tag': 'pharmacy_search', 'patterns': ['Find ...
# 10    {'tag': 'search_pharmacy_by_name', 'patterns':...
# 11    {'tag': 'hospital_search', 'patterns': ['Looku...
# 12    {'tag': 'search_hospital_by_params', 'patterns...
# 13    {'tag': 'search_hospital_by_type', 'patterns':...
# Name: intents, dtype: object

# %%
df
# Out:
#                                               intents
# 0   {'tag': 'greeting', 'patterns': ['Hi there', '...
# 1   {'tag': 'goodbye', 'patterns': ['Bye', 'See yo...
# 2   {'tag': 'thanks', 'patterns': ['Thanks', 'Than...
# 3   {'tag': 'noanswer', 'patterns': [], 'responses...
# 4   {'tag': 'options', 'patterns': ['How you could...
# 5   {'tag': 'adverse_drug', 'patterns': ['How to c...
# 6   {'tag': 'blood_pressure', 'patterns': ['Open b...
# 7   {'tag': 'blood_pressure_search', 'patterns': [...
# 8   {'tag': 'search_blood_pressure_by_patient_id',...
# 9   {'tag': 'pharmacy_search', 'patterns': ['Find ...
# 10  {'tag': 'search_pharmacy_by_name', 'patterns':...
# 11  {'tag': 'hospital_search', 'patterns': ['Looku...
# 12  {'tag': 'search_hospital_by_params', 'patterns...
# 13  {'tag': 'search_hospital_by_type', 'patterns':...

# %%
adverse_drug_reaction = []

# %%
df = pd.read_csv('2021VAERSDATA.csv')
# Out:
# /home/alain/Documents/third_year/S2_S6/AI_DM/projects/NLP/case/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (7,12,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# (Index(['VAERS_ID', 'RECVDATE', 'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX',
#         'RPT_DATE', 'SYMPTOM_TEXT', 'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT',
#         'HOSPITAL', 'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE',
#         'ONSET_DATE', 'NUMDAYS', 'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY',
#         'OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX', 'SPLTTYPE',
#         'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT',
#         'ALLERGIES'],
#        dtype='object'),
#  <bound method NDFrame.rolling of        VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
#  0        916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
#  1        916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
#  2        916602  01/01/2021    WA     23.0     23.0      NaN   F      NaN
#  3        916603  01/01/2021    WA     58.0     58.0      NaN   F      NaN
# ...

# %%
df.head(3)
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 1    916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 2    916602  01/01/2021    WA     23.0     23.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
# 2  About 15 minutes after receiving the vaccine, ...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                               None
# 1  Patient residing at nursing facility. See pati...
# 2                                               None
#
#                                              HISTORY PRIOR_VAX SPLTTYPE  \
# 0                                               None       NaN      NaN
# ...

# %%
df.describe()
# Out:
#            VAERS_ID       AGE_YRS       CAGE_YR    CAGE_MO     HOSPDAYS  \
# count  3.412100e+04  30933.000000  26791.000000  83.000000  2857.000000
# mean   9.813066e+05     51.471923     51.135381   0.084337     3.752888
# std    6.204535e+04     18.521742     18.633316   0.178395     3.878654
# min    9.166000e+05      0.080000      0.000000   0.000000     1.000000
# 25%    9.264640e+05     37.000000     36.000000   0.000000     1.000000
# 50%    9.468370e+05     50.000000     49.000000   0.000000     3.000000
# 75%    1.047069e+06     65.000000     65.000000   0.000000     5.000000
# max    1.115348e+06    115.000000    106.000000   0.700000    39.000000
#
#             NUMDAYS     FORM_VERS
# count  31194.000000  34121.000000
# mean      21.077066      1.998124
# std      644.834400      0.043269
# min        0.000000      1.000000
# 25%        0.000000      2.000000
# 50%        1.000000      2.000000
# 75%        3.000000      2.000000
# max    36896.000000      2.000000
